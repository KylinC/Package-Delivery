# %%
import pandas as pd
import numpy as np
import csv

# %%
trk = pd.read_csv("truck.csv")
trk
# Out:
#         Unnamed: 0  Departure city index  Arrival city index  \
# 0           107677                     1                   4
# 1            96576                     1                   7
# 2            23048                     1                   9
# 3            25190                     1                  12
# 4            97049                     1                  26
# 5            38845                     1                  34
# 6            28382                     1                  39
# 7           113623                     1                  56
# 8            12744                     1                  60
# 9            47652                     1                  61
# 10           18459                     1                  63
# 11           74853                     1                  64
# 12          100874                     1                  69
# 13           38769                     1                  70
# ...

# %%
len(trk)
# Out:
# 114689

# %%
import time

# %%
start3 = time.time()
for idx, row in trk.iterrows():
    row["Departure min"]
end3 = time.time()

# %%
end3 -start3
# Out:
# 3.1785311698913574

# %%
trk
# Out:
#         Unnamed: 0  Departure city index  Arrival city index  \
# 0           107677                     1                   4
# 1            96576                     1                   7
# 2            23048                     1                   9
# 3            25190                     1                  12
# 4            97049                     1                  26
# 5            38845                     1                  34
# 6            28382                     1                  39
# 7           113623                     1                  56
# 8            12744                     1                  60
# 9            47652                     1                  61
# 10           18459                     1                  63
# 11           74853                     1                  64
# 12          100874                     1                  69
# 13           38769                     1                  70
# ...

# %%
start5 = time.time()
trk = pd.DataFrame(trk)
for idx, row in trk.iterrows():
    row["Departure min"]
end5 = time.time()

# %%
end5- start5
# Out:
# 3.1815273761749268

# %%
start6 = time.time()
for row in trk.itertuples():
    getattr(row, "_7")
end6 = time.time()

# %%
end6 - start6
# Out:
# 0.19553685188293457
