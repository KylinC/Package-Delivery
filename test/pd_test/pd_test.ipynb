# %%
import pandas as pd

dis = pd.read_csv("dis.csv")

# %%
dis
# Out:
#               0  649.814593656508  107.556873931518  496.0861042577  \
# 0    649.814594          0.000000        587.739350      539.837185
# 1    107.556874        587.739350          0.000000      556.674768
# 2    496.086104        539.837185        556.674768        0.000000
# 3    286.607075        149.236414        250.441418      151.837545
# 4    534.309558        206.478785        286.695999      471.818800
# 5    582.170970        511.642259        568.645792      510.755536
# 6    130.029215        448.148919        282.643122      157.114984
# 7    285.691751        415.621393        305.638390      459.194115
# 8    185.409143        507.453244        366.684227      416.138548
# 9    521.910609        310.907319        422.513681      370.195760
# 10   252.539500        365.389117        164.160540       91.582047
# 11   142.507329        429.415054        115.582519      344.191090
# 12   321.560894        104.714241        200.056142      101.564649
# ...

# %% [markdown]
# # Series

# %%
import numpy as np
s = pd.Series([1, 2, 3, np.nan])

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# dtype: float64

# %%
s[1]
# Out:
# 2.0

# %% [markdown]
# # Date & DataFrame

# %%
dates = pd.date_range("20190607", periods=2)
dates
# Out:
# DatetimeIndex(['2019-06-07', '2019-06-08'], dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(2, 4), index=dates, 
                  columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2019-06-07 -0.876353  0.858339  0.117801  0.301558
# 2019-06-08  0.243504  1.009587  1.178004  0.411487

# %%
df2 = pd.DataFrame({
    'A': 1,
    'B': pd.Timestamp('20190607'),
    'C': pd.Series(1, index=list('hjkl;'), dtype='float32'),
#     'D': np.array([3] * 5, dtype='int32'),
#     'E': pd.Categorical(["t"]),
    'F': "asdasd"
})

df2
# Out:
#    A          B    C       F
# h  1 2019-06-07  1.0  asdasd
# j  1 2019-06-07  1.0  asdasd
# k  1 2019-06-07  1.0  asdasd
# l  1 2019-06-07  1.0  asdasd
# ;  1 2019-06-07  1.0  asdasd

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
dis.dtypes
# Out:
# 0                   float64
# 649.814593656508    float64
# 107.556873931518    float64
# 496.0861042577      float64
# 286.60707458843     float64
# 534.309557577318    float64
# 582.170969942578    float64
# 130.02921518909     float64
# 285.69175094638     float64
# 185.409143467069    float64
# 521.910609312307    float64
# 252.539500286293    float64
# 142.507328927367    float64
# 321.560893896392    float64
# 629.473192969405    float64
# 260.854158787418    float64
# 54.0822658389001    float64
# 578.636307219682    float64
# 574.713271891816    float64
# 573.37546007477     float64
# 260.696006199706    float64
# 436.826117030718    float64
# 612.912564575287    float64
# 267.379541734649    float64
# 152.032779251754    float64
# 465.523963670854    float64
# 331.483410274782    float64
# 387.333118834024    float64
# 96.8477797815494    float64
# 302.971950787491    float64
#                      ...
# 475.875209201338    float64
# 462.934647452334    float64
# ...

# %%
dis_df = pd.DataFrame(dis.values, 
                      index=range(len(dis)), 
                      columns=range(len(dis)+1))
dis_df
# Out:
#             0           1           2           3           4           5    \
# 0    649.814594    0.000000  587.739350  539.837185  149.236414  206.478785
# 1    107.556874  587.739350    0.000000  556.674768  250.441418  286.695999
# 2    496.086104  539.837185  556.674768    0.000000  151.837545  471.818800
# 3    286.607075  149.236414  250.441418  151.837545    0.000000  511.632439
# 4    534.309558  206.478785  286.695999  471.818800  511.632439    0.000000
# 5    582.170970  511.642259  568.645792  510.755536  183.832288  603.047146
# 6    130.029215  448.148919  282.643122  157.114984  227.370150  141.188339
# 7    285.691751  415.621393  305.638390  459.194115   89.709361  567.490825
# 8    185.409143  507.453244  366.684227  416.138548  508.180643  496.359439
# 9    521.910609  310.907319  422.513681  370.195760  498.223904  329.572962
# 10   252.539500  365.389117  164.160540   91.582047  220.145906  580.653004
# ...

# %% [markdown]
# # sort_index & sort_value

# %%
df3 = pd.DataFrame(np.random.rand(3, 3), index=[2, 3, 1], columns=[1, 3, 2])
df3
# Out:
#           1         3         2
# 2  0.078363  0.002052  0.841651
# 3  0.099784  0.392011  0.366484
# 1  0.499235  0.580648  0.909049

# %%
df3.sort_index(axis=0)
# Out:
#           1         3         2
# 1  0.499235  0.580648  0.909049
# 2  0.078363  0.002052  0.841651
# 3  0.099784  0.392011  0.366484

# %%
df3.sort_index(axis=1)
# Out:
#           1         2         3
# 2  0.078363  0.841651  0.002052
# 3  0.099784  0.366484  0.392011
# 1  0.499235  0.909049  0.580648

# %%
df3.sort_values(by=2)
# Out:
#           1         3         2
# 3  0.099784  0.392011  0.366484
# 2  0.078363  0.002052  0.841651
# 1  0.499235  0.580648  0.909049

# %%
df3.sort_values(by=2, ascending=False)
# Out:
#           1         3         2
# 1  0.499235  0.580648  0.909049
# 2  0.078363  0.002052  0.841651
# 3  0.099784  0.392011  0.366484
