# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_plane=pd.read_csv("sourceData/TableD-Plane.csv")

# %%
df_plane=pd.DataFrame(csv_plane)

# %%
df_plane
# Out:
#       Departure city index  Arrival city index  \
# 0                      456                 190
# 1                        7                  52
# 2                       52                 345
# 3                       93                 512
# 4                       97                 274
# 5                      101                 642
# 6                      608                 144
# 7                      360                 490
# 8                      398                 442
# 9                      203                  78
# 10                     586                 405
# 11                     512                 591
# 12                     147                  84
# 13                     407                 391
# 14                     543                 597
# 15                     412                 617
# 16                     233                 270
# 17                     135                 424
# 18                     351                 510
# ...

# %%
df_plane.columns
# Out:
# Index(['Departure city index', 'Arrival city index',
#        'Average delay per trip (minutes)', 'Speed (km/h)',
#        'Cost for 50km for every 1kg good ', 'Departure time'],
#       dtype='object')

# %%
df_plane=df_plane.sort_values(by=["Departure city index","Arrival city index","Departure time","Cost for 50km for every 1kg good "])

# %%
df_plane
# Out:
#       Departure city index  Arrival city index  \
# 9048                     5                  18
# 305                      5                  39
# 2611                     5                  49
# 3276                     5                  54
# 2343                     5                  72
# 1946                     5                  93
# 4765                     5                  93
# 1015                     5                 105
# 5737                     5                 119
# 1911                     5                 125
# 8621                     5                 135
# 4185                     5                 150
# 949                      5                 154
# 522                      5                 170
# 4580                     5                 184
# 8243                     5                 184
# 1333                     5                 196
# 1038                     5                 202
# 6915                     5                 202
# ...
